# %%
# Visualization of gift amout per gift allocation

import pandas as pd
import matplotlib.pyplot as plt

farben = ["#3498db", "#2ecc71", "#e74c3c"]  # Beispiel: Blau, Grün, Rot

df = pd.read_excel("advancement_donations_and_giving_demo.xls", engine="xlrd")
gruppen = df.groupby("Gift Allocation")["Gift Amount"].sum()
gruppen.plot(kind="bar", color=farben, title="Gift Amount per Category")

for index, value in enumerate(gruppen):
    plt.text(index, value, f"{round(value, -3):,}", ha="center", va="bottom")

plt.xlabel("Category")
plt.ylabel("Gift Amount in €")
plt.gca().get_yaxis().set_major_formatter(plt.FuncFormatter(lambda x, _: f"{x:,.0f} €"))
