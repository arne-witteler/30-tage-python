# %%
import pandas as pd

df = pd.read_excel("advancement_donations_and_giving_demo.xls", engine="xlrd")
print(df["Gift Amount"].mean())
# Out:
# 6305.33018144646

# %%
# Visualization of gift amout per gift allocation

import matplotlib.pyplot as plt

print(df.columns)
gruppen = df.groupby("Gift Allocation")["Gift Amount"].sum()
gruppen.head()
gruppen.plot(kind="bar", title="Gift Amount pro Kategorie")
# Out:
# Index(['Allocation Subcategory', 'City', 'College', 'Gift Allocation',
#        'Gift Amount', 'Gift Date', 'Major', 'Prospect ID', 'State'],
#       dtype='object')
# <Axes: title={'center': 'Gift Amount pro Kategorie'}, xlabel='Gift Allocation'>
